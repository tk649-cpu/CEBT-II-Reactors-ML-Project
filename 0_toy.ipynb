# %%
# install required packages in jupyter lab in the computer class
pip install -r requirements.txt
# Out:
#   Cell In[2], line 2
#     pip install -r requirements.txt
#         ^
# SyntaxError: invalid syntax

# %%
# Or install required packages in your own python environment, run this instead
# Before installing the following packages, try to install conda and IDE like Vscode, for reference:
#   - https://www.anaconda.com
#   - https://code.visualstudio.com

# !pip install bayesian-optimization==3.1.0
# !pip install ipykernel==7.0.0
# !pip install ipywidgets==8.1.7
# !pip install jupyter_client==8.6.3
# !pip install jupyter_core==5.8.1
# !pip install jupyterlab_widgets==3.0.15
# !pip install numpy==2.3.3
# !pip install pandas==2.3.3
# !pip install plotly==6.3.1
# !pip install scikit-learn==1.7.2
# !pip install scipy==1.16.2
# !pip install nbformat==5.10.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bayesian-optimization==3.1.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (3.1.0)
# Requirement already satisfied: colorama>=0.4.6 in c:\users\taher\appdata\roaming\python\python313\site-packages (from bayesian-optimization==3.1.0) (0.4.6)
# Requirement already satisfied: numpy>=2.1.3 in c:\users\taher\appdata\roaming\python\python313\site-packages (from bayesian-optimization==3.1.0) (2.3.5)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from bayesian-optimization==3.1.0) (1.7.2)
# Requirement already satisfied: scipy>=1.14.1 in c:\users\taher\appdata\roaming\python\python313\site-packages (from bayesian-optimization==3.1.0) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.0.0->bayesian-optimization==3.1.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.0.0->bayesian-optimization==3.1.0) (3.6.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipykernel==7.0.0
#   Downloading ipykernel-7.0.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (9.7.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipykernel==7.0.0) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel==7.0.0) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\taher\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel==7.0.0) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel==7.0.0) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter-client>=8.0.0->ipykernel==7.0.0) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==7.0.0) (4.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\taher\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel==7.0.0) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.0.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.0.0) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\taher\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel==7.0.0) (0.2.3)
# Downloading ipykernel-7.0.0-py3-none-any.whl (118 kB)
# Installing collected packages: ipykernel
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 7.1.0
#     Uninstalling ipykernel-7.1.0:
#       Successfully uninstalled ipykernel-7.1.0
# Successfully installed ipykernel-7.0.0
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ipywidgets==8.1.7
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipywidgets==8.1.7) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipywidgets==8.1.7) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipywidgets==8.1.7) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipywidgets==8.1.7) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipywidgets==8.1.7) (3.0.16)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\taher\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.1.7) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets==8.1.7) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets==8.1.7) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets==8.1.7) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\taher\appdata\roaming\python\python313\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets==8.1.7) (0.2.3)
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Installing collected packages: ipywidgets
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.1.8
#     Uninstalling ipywidgets-8.1.8:
#       Successfully uninstalled ipywidgets-8.1.8
# Successfully installed ipywidgets-8.1.7
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter_client==8.6.3 in c:\users\taher\appdata\roaming\python\python313\site-packages (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter_client==8.6.3) (5.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter_client==8.6.3) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter_client==8.6.3) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter_client==8.6.3) (6.5.2)
# Requirement already satisfied: traitlets>=5.3 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter_client==8.6.3) (5.14.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter_client==8.6.3) (4.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\taher\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->jupyter_client==8.6.3) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting jupyter_core==5.8.1
#   Downloading jupyter_core-5.8.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter_core==5.8.1) (4.5.0)
# Collecting pywin32>=300 (from jupyter_core==5.8.1)
#   Downloading pywin32-311-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: traitlets>=5.3 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter_core==5.8.1) (5.14.3)
# Downloading jupyter_core-5.8.1-py3-none-any.whl (28 kB)
# Downloading pywin32-311-cp313-cp313-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------- ----------------------- 3.9/9.5 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 25.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 23.5 MB/s eta 0:00:00
# Installing collected packages: pywin32, jupyter_core
#
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#   Attempting uninstall: jupyter_core
#    ---------------------------------------- 0/2 [pywin32]
#     Found existing installation: jupyter_core 5.9.1
#    ---------------------------------------- 0/2 [pywin32]
#    -------------------- ------------------- 1/2 [jupyter_core]
#    -------------------- ------------------- 1/2 [jupyter_core]
#    -------------------- ------------------- 1/2 [jupyter_core]
#    -------------------- ------------------- 1/2 [jupyter_core]
#    -------------------- ------------------- 1/2 [jupyter_core]
#    -------------------- ------------------- 1/2 [jupyter_core]
#     Uninstalling jupyter_core-5.9.1:
#    -------------------- ------------------- 1/2 [jupyter_core]
#    -------------------- ------------------- 1/2 [jupyter_core]
#    -------------------- ------------------- 1/2 [jupyter_core]
#       Successfully uninstalled jupyter_core-5.9.1
#    -------------------- ------------------- 1/2 [jupyter_core]
#    -------------------- ------------------- 1/2 [jupyter_core]
#    ---------------------------------------- 2/2 [jupyter_core]
#
# Successfully installed jupyter_core-5.8.1 pywin32-311
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting jupyterlab_widgets==3.0.15
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Installing collected packages: jupyterlab_widgets
#   Attempting uninstall: jupyterlab_widgets
#     Found existing installation: jupyterlab_widgets 3.0.16
#     Uninstalling jupyterlab_widgets-3.0.16:
#       Successfully uninstalled jupyterlab_widgets-3.0.16
# Successfully installed jupyterlab_widgets-3.0.15
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy==2.3.3
#   Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    --------------- ------------------------ 5.0/12.8 MB 28.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 33.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 31.4 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.5
#     Uninstalling numpy-2.3.5:
#       Successfully uninstalled numpy-2.3.5
# Successfully installed numpy-2.3.3
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas==2.3.3
#   Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from pandas==2.3.3) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\taher\appdata\roaming\python\python313\site-packages (from pandas==2.3.3) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas==2.3.3)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.3.3)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\taher\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas==2.3.3) (1.17.0)
# Downloading pandas-2.3.3-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    --------------------------- ------------ 7.6/11.0 MB 38.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 34.8 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
# ...
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed pandas-2.3.3 pytz-2025.2 tzdata-2025.2
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly==6.3.1
#   Downloading plotly-6.3.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\taher\appdata\roaming\python\python313\site-packages (from plotly==6.3.1) (2.12.0)
# Requirement already satisfied: packaging in c:\users\taher\appdata\roaming\python\python313\site-packages (from plotly==6.3.1) (25.0)
# Downloading plotly-6.3.1-py3-none-any.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.8 MB 14.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.8 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 8.9 MB/s eta 0:00:00
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 6.5.0
#     Uninstalling plotly-6.5.0:
#       Successfully uninstalled plotly-6.5.0
# Successfully installed plotly-6.3.1
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn==1.7.2 in c:\users\taher\appdata\roaming\python\python313\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from scikit-learn==1.7.2) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from scikit-learn==1.7.2) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from scikit-learn==1.7.2) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from scikit-learn==1.7.2) (3.6.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy==1.16.2
#   Downloading scipy-1.16.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\taher\appdata\roaming\python\python313\site-packages (from scipy==1.16.2) (2.3.3)
# Downloading scipy-1.16.2-cp313-cp313-win_amd64.whl (38.5 MB)
#    ---------------------------------------- 0.0/38.5 MB ? eta -:--:--
#    ----- ---------------------------------- 5.5/38.5 MB 28.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 10.7/38.5 MB 26.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.8/38.5 MB 27.7 MB/s eta 0:00:01
#    -------------------- ------------------- 20.2/38.5 MB 24.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 23.1/38.5 MB 22.5 MB/s eta 0:00:01
#    ------------------------------ --------- 29.6/38.5 MB 24.1 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/38.5 MB 25.1 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.5 MB 25.4 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 23.0 MB/s eta 0:00:00
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
# Successfully installed scipy-1.16.2
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nbformat==5.10.4 in c:\users\taher\appdata\roaming\python\python313\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\taher\appdata\roaming\python\python313\site-packages (from nbformat==5.10.4) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\taher\appdata\roaming\python\python313\site-packages (from nbformat==5.10.4) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\taher\appdata\roaming\python\python313\site-packages (from nbformat==5.10.4) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\taher\appdata\roaming\python\python313\site-packages (from nbformat==5.10.4) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jsonschema>=2.6->nbformat==5.10.4) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jsonschema>=2.6->nbformat==5.10.4) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jsonschema>=2.6->nbformat==5.10.4) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jsonschema>=2.6->nbformat==5.10.4) (0.29.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat==5.10.4) (4.5.0)
# Requirement already satisfied: pywin32>=300 in c:\users\taher\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat==5.10.4) (311)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Toy Case
#
# This case employs a simple reaction `A > B` performed in a batch reactor to introduce the provided modelling environment.
#
# <div><center><img src="https://upload.wikimedia.org/wikipedia/commons/1/15/Batch_reactor_STR.svg" width="150"/></center></div>
#
# The mass balance equation for batch reactor is
# $$\frac{dc}{dt} = r_r$$
# The reaction rate constant of `A > B` follows Arrhenius equation
# $$k = A\cdot\exp{(-\frac{E_a}{RT})}$$
# We reparameterise Arrhenius with reference to 20 oC
# $$k = k_{ref}\cdot\exp{(-\frac{E_a}{R}(\frac{1}{T} - \frac{1}{293.15}))}$$
# The reaction rate follows power law with respect to concentrations of reactants
# $$r_r = k\prod c^n$$

# %%
# Import required python libraries
# Run this cell to set up the modelling environment
import pandas as pd
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

# Define the phenomenon dictionary to define the model structure
# A dictionary is a key-value mapping. For more info, please look 
# at https://docs.python.org/3/tutorial/datastructures.html#dictionaries
# Mass accumulation and flow pattern phenomenons are given in string, 
# Mass transport phenomenons are collected in a list, though it's empty here.
phenos = {
    "Mass accumulation":    "Batch",
    "Flow pattern":         "Well_Mixed",
    "Mass transport":       [],
}

# Import the toy case study which we'll work on in this notebook
from cases.toy_case import ToyCase
toy_case = ToyCase(phenos)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %% [markdown]
# #### Parameter Setup
# As modelling parameters are associated with different dimensions (solid, liquid, stream, reaction, and species)
#
# All parameters are indicated as a dictionary as
# ```
# {
#     "param":    "xxx",
#     "solid":    "xxx",
#     "gas":      "xxx",
#     "stream":   "xxx",
#     "reaction": "xxx",
#     "species":  "xxx"
# }
# ```
# in this provided modelling environment.
#
# Example parameter dictionaries:
# > - **Operation parameters**
# >   - {"param": "Temperature"}
# >   - {"Param": "Concentration", "stream": "Stream_1", "species": "A"}
# > Concentration is associated with stream and species
# > - **Kinetics parameters**
# >   - {"param": "Activation_Energy", "stream": "Stream_1", "reaction": "A > B"}
# >   - {"param": "Referenced_Reaction_Rate_Constant", "stream": "Stream_1", "reaction": "A > B"}
# > Activation_Energy and Referenced_Reaction_Rate_Constant are associated with stream and reaction
#
# #### Unit Setup
#
# Parameter setup can be found in the method `toy_case.var2unit()`
#
# | Parameter                         | Unit   |
# | --------------------------------- | ------ |
# | Referenced_Reaction_Rate_Constant |        |
# | Activation_Energy                 | kJ/mol |
# | Temperature                       | oC     |
# | Concentration                     | mol/L  |
# | Batch_Time                        | min    |

# %% [markdown]
# ### Model Simulation
# - Print model kinetics parameters and operation parameters
# - Set operation condition example and plot the concentration curves against operation time
# - Plot B concentration profiles at varied temperatures
# - Plot B concentration profiles at varied initial A concentrations

# %%
# List reaction parameters
print("Reaction parameters:")
for reaction_param in toy_case.reaction_params():
    print(reaction_param)
# Out:
# Reaction parameters:
# ({'param': 'Activation_Energy', 'stream': 'Batch_Feed', 'reaction': 'A > B'}, 80.0)
# ({'param': 'Referenced_Reaction_Rate_Constant', 'stream': 'Batch_Feed', 'reaction': 'A > B'}, 0.0001)
# ({'param': 'Stoichiometric_Coefficient', 'reaction': 'A > B', 'species': 'A'}, -1)
# ({'param': 'Stoichiometric_Coefficient', 'reaction': 'A > B', 'species': 'B'}, 1)
# ({'param': 'Partial_Order', 'reaction': 'A > B', 'species': 'A'}, 1)

# %%
# List operation parameters
print("Operation parameters:")
for operation_param in toy_case.operation_params():
    print(operation_param)
# Out:
# Operation parameters:
# ({'param': 'Concentration', 'stream': 'Batch_Feed', 'species': 'A'}, None)
# ({'param': 'Temperature'}, None)
# ({'param': 'Batch_Time'}, None)

# %%
# Model simulation and plot concentration profiles
# A concentration   [A] = 1 mol/L
# Temperature       T = 50.0 oC
# Batch time        t_b = 60.0 min
operation_params = [
    ({"param": "Concentration", "stream": "Batch_Feed", "species": "A"}, 1.0), # mol/L
    ({"param": "Temperature"}, 50.0), # oC
    ({"param": "Batch_Time"}, 60.0), # min
]
toy_case.plot_simulation_profiles(operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="d17a8abc-6dae-4398-8fdb-60dd1e0940ff" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d17a8abc-6dae-4398-8fdb-60dd1e0940ff")) {                    Plotly.newPlot(                        "d17a8abc-6dae-4398-8fdb-60dd1e0940ff",                        [{"hovertemplate":"Species=A\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eConcentration (mol\u002fL)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"A","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAAzMzMzMzPTPzMzMzMzM+M\u002fzczMzMzM7D8zMzMzMzPzPwAAAAAAAPg\u002fzczMzMzM\u002fD\...\\...\u002fNMQJqZmZmZGU1AAAAAAABATUBmZmZmZmZNQM3MzMzMjE1AMzMzMzOzTUCamZmZmdlNQAAAAAAAAE5A"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAA
39A\u002fZ2g5TL300D+9Z+sEZgrRP9LoF8UEINE\u002fmi5BkZk10T8GseZtJEvRPwkdhV+lYNE\u002fjlSWahx20T+DbpGTiYvRP9a26t7soNE\u002fcq4TUUa20T8\u002fC3vulcvRPya4jLvb4NE\u002fDdWxvBf20T\u002fbtlD2SQvSP3TnzGxyINI\u002fuyWHJJE10j+RZd0hpkrSP9bPKmmxX9I\u002fa8LH\u002frJ00j8r0AnnqonSP\u002 ...

# %%
# B concentration profiles under vared A concentrations
# Set A concentration to a list of values: [0.5, 1.0, 1.5, 2.0]
operation_params = [
    ({"param": "Concentration", "stream": "Batch_Feed", "species": "A"}, [0.5, 1.0, 1.5, 2.0]), # mol/L
    ({"param": "Temperature"}, 50.0), # oC
    ({"param": "Batch_Time"}, 60.0), # min
]
toy_case.plot_product_profile_with_A_concs(operation_params)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="d7970ed4-f08b-4635-9561-e7ab46f26bb2" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d7970ed4-f08b-4635-9561-e7ab46f26bb2")) {                    Plotly.newPlot(                        "d7970ed4-f08b-4635-9561-e7ab46f26bb2",                        [{"hovertemplate":"A concentration (mol\u002fL)=0.5\u003cbr\u003eTime (min)=%{x}\u003cbr\u003eB concentration (mol\u002fL)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.5","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0.5","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"AAAAAAAAAAAzMzMzMzPTPzMzMzMzM+M\u002fzczMzMzM7D8zMzMzMzPzPwAAAAAAAPg\u002fzczMzMzM\u002fD\...\\...\u002fNMQJqZmZmZGU1AAAAAAABATUBmZmZmZmZNQM3MzMzMjE1AMzMzMzOzTUCamZmZmdlNQAAAAAAAAE5A"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAAACYFlpxyiOGP7Hp3A575pU\u002f9hfugJI\u002foD9bOU7UlG6lP+jvd+7mgKo\u002f1lGHRyZ3rz\u002fDzCi79yiyP740Y67siLQ\u002fyQsAzbzbtj9lAzA5ryG5P\u002fZWslkLW7s\u002fwggWNxiIvT+zZd8JG6m\u002fP64CRJ0r38A\u002f9GS\u002fMAfkwT8W8JMjQOPCP8tf7nH13MM\u002fHhX2L0XRxD9qFs2JTMDFP1wPkMMnqsY\u002fc9Gdp\u002fOOxz9vanMf0G7IP8ViusvYSck\u002fp+8kMiggyj\u002fIW18T2PHKP1wHEGsBv8s\u002fF2jXb7yHzD8vCVCTIEzNP1eLDoJEDM4\u002fyKShIz7Izj82IZKaIoDPPw6MECUDGtA\u002fdQ5ClQFy0D96AnSFGcjQP9sTkIJVHNE\u002fRDCX1L9u0T9Th6F+Yr\u002fRP5GK3j5HDtI\u002feO2Ujndb0j93pSKi\u002fKbSP+Tp\u002fGjf8NI\u002fBTSwjSg50z8VP+B14H\u002fTP3BI94wPxdM\u002fFfdY778I1D\u002fBHZ1F+krUP42R4KjGi9Q\u002fk90E\u002fCzL1D\u002fxQrDrNAnVP8W4Te7lRdU\u002fLuwMREeB1T9OQOL2X7vVP0TOhto29NU\u002fNmV4jNIr1j9JivlzOWLWP6x9rZhyl9Y\u002fsh9Pp4XL1j8cG+QBef7WPwqJettSMNc\u002fwGSwPBlh1z+mi7MD
# In this notebook, we use a simple grid-based experimental approach.
# Recall that
# $k = k_{ref}\cdot\exp{(-\frac{E_a}{R}(\frac{1}{T} - \frac{1}{293.15}))}$, $r_r = k\prod c^n$
# By varying residence time and initial A concentration, we can calibrate $k$ for each temperature
# By varying temperature, we can calibrate the Activation Energy $E_a$

# %%
# Print column names for operation parameters
print("Column names for operation parameters:")
for name_ind in toy_case.operation_name2ind():
    print(name_ind)
# Out:
# Column names for operation parameters:
# ('A_conc', {'param': 'Concentration', 'stream': 'Batch_Feed', 'species': 'A'})
# ('temp', {'param': 'Temperature'})
# ('t_b', {'param': 'Batch_Time'})

# %% [markdown]
# ### Prediction error minimisation
# Assume these data are obtained from experiments. Then, the model is fitted by minimising the prediction error on these operation conditions
# $Error = Mean((c_{measured,B} - c_{predicted,B})^2)$
# The quasi-Newton algorithm `L-BFGS-B` is used to minimise this error
# Find original codes of the `calibrate` method in `cases/toy_case.py` file

# %%
# First, we design grid experiment points and calibrate k_ref at referenced temperature (25 oC)
# Run simulation to mimic experiment data
exp_data1 = {
    "A_conc": [0.25, 0.25, 0.75, 0.75],
    "temp":   [  25,   25,   25,   25],
    "t_b":    [  30,   60,   30,   60],
}
exp_dataset1 = pd.DataFrame(exp_data1)
exp_dataset1 = toy_case.run_dataset(exp_dataset1)

# Define parameter bound for calibration
cal_param_bounds = [
    (
        {
            "param": "Referenced_Reaction_Rate_Constant", 
            "stream": "Batch_Feed", 
            "reaction": "A > B"
        },
        (1e-6, 1e-3)
    )
]

# Calbrate referenced reaction rate constant
calibrated_kref = toy_case.calibrate(cal_param_bounds, exp_dataset1)[0]
print(calibrated_kref)
# Out:
# ({'param': 'Referenced_Reaction_Rate_Constant', 'stream': 'Batch_Feed', 'reaction': 'A > B'}, 0.0001)

# %%
# Then, we design grid experiment points for 50 and 75 oC to calibrate activation energy
# Run simulation to mimic experiment data
exp_data2 = {
    "A_conc": [0.25, 0.25, 0.75, 0.75, 0.25, 0.25, 0.75, 0.75],
    "temp":   [  50,   50,   50,   50,   75,   75,   75,   75],
    "t_b":    [  30,   60,   30,   60,   30,   60,   30,   60],
}
exp_dataset2 = pd.DataFrame(exp_data2)
exp_dataset2 = toy_case.run_dataset(exp_dataset2)

# Define parameter bound for calibration
cal_param_bounds = [
    (
        {
            "param": "Referenced_Reaction_Rate_Constant", 
            "stream": "Batch_Feed", 
            "reaction": "A > B"
        },
        (1e-4, 1e-4)
    ), 
    (
        {
            "param": "Activation_Energy", 
            "stream": "Batch_Feed", 
            "reaction": "A > B"
        },
        (20, 100)
    )
]

# Calbrate activation energy
calibrated_params = toy_case.calibrate(cal_param_bounds, exp_dataset2)
for calibrated_param in calibrated_params:
    print(calibrated_param)
# Out:
# ({'param': 'Activation_Energy', 'stream': 'Batch_Feed', 'reaction': 'A > B'}, 60.080864)
# ({'param': 'Referenced_Reaction_Rate_Constant', 'stream': 'Batch_Feed', 'reaction': 'A > B'}, 0.0001)
